# %%
import torch
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
import csv
import os
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from torchtext.data import get_tokenizer
import string
import math
from transformers import BertTokenizer, BertModel
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn

# %%
# Choix de device

# device = 'cpu'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Définition de START et END pour éviter des fautes de frappe :

START = "<start>"
END = "<end>"

MAX_VOCAB_SIZE = 1000
MAX_SEQ_LENGTH = 25

BATCH_SIZE = 16

EPOCHS = 20

DATASET_PATH = 'dataset/Flicker8k_Dataset/'

# %%
#
url_flicker_train = 'flickr_8k_train_dataset.txt';
def flicker_source(fName):
    """
    Une fonction qui charge un jeu de données, et renvoie un générateur
    permettant de le parcourir.

    Résultat:
        un générateur renvoyant des couples de string "nom d'image", "label de l'image"
    """
    images = []
    descriptions = []
    with open(fName, encoding='utf-8') as f:
        reader = csv.reader(f, delimiter='\t')
        next(reader) # skip the first row (column headers)
        for row in reader:
            image, texte = row
            images.append(image)
            descriptions.append(texte)
        return images, descriptions

def flicker_train():
    return flicker_source(url_flicker_train)

# %%
def preprocess_text(captions):
    nltk.download('stopwords')
    STOPWORDS = set(stopwords.words('english'))
    nltk.download('wordnet')
    lemmatizer = WordNetLemmatizer()

    # Tokenization des captions
    tokenizer = get_tokenizer("basic_english")
    tokenized_captions = []
    descriptions = []
    for caption in captions:
        description = caption.lower()
        description = description.replace(START, '')
        description = description.replace(END, '')
        description = description.translate(str.maketrans('', '', string.punctuation))
        description = description.split()
        description = [lemmatizer.lemmatize(word) for word in description if word not in STOPWORDS]
        description = ' '.join(description)
        descriptions.append(description)
        
    corpus = [word for description in descriptions for word in description.split(' ')]
    vocab = get_top_words(descriptions, math.ceil(len(set(corpus))*0.25))
                              
    preprocessed_descriptions = []
    for description in descriptions:
        valid_words = []
        for word in description.split(' '):
            if word in vocab:
                valid_words.append(word)
        preprocessed_descriptions.append(" ".join(valid_words))   
                          
    return preprocessed_descriptions

def get_top_words(descriptions, max_features=100):
    corpus = [word for description in descriptions for word in description.split(' ')]
    
    # Créer un vecteur de TF-IDF
    vectorizer = TfidfVectorizer(max_features=max_features)
    X = vectorizer.fit_transform(corpus)

    # Récupérer les mots les plus importants
    return list(vectorizer.vocabulary_.keys())

# %%
training_images, training_descriptions = flicker_train()

# %%
descriptions = preprocess_text(training_descriptions)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# print(descriptions)

# %%
# Charger le tokenizer BERT
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Charger le modèle BERT
model = BertModel.from_pretrained('bert-base-uncased')

model.to(device)
def extract_text_features(description):
    tokens = tokenizer.encode(description, add_special_tokens=True)

    # Conversion des tokens en tenseur PyTorch
    tokens_tensor = torch.tensor([tokens]).to(device)

    # Encodage du texte avec le modèle BERT
    with torch.no_grad():
        outputs = model(tokens_tensor)

    # Récupération de la représentation du texte
    last_hidden_state = outputs[0]
    return torch.mean(last_hidden_state, dim=1).squeeze()
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
description_features = []
for description in descriptions:
    description_features.append(extract_text_features(description))
    
# print(description_features)

# %%
 print(description_features[4].shape)
# Out:
# torch.Size([768])

# %%
model = models.resnet18(pretrained=True)
model.to(device)

def get_image_feature(path):
    img = Image.open(path)
    preprocess = transforms.Compose([
       transforms.Resize(256),
       transforms.CenterCrop(224),
       transforms.ToTensor(),
       transforms.Normalize(mean=[0.485, 0.456, 0.406],
                            std=[0.229, 0.224, 0.225])
    ])
    img_tensor = preprocess(img).to('cuda')
    img_tensor.unsqueeze_(0)

    # Utilisez le modèle pour extraire les features
    with torch.no_grad():
        features = model.conv1(img_tensor)
        features = model.bn1(features)
        features = model.relu(features)
        features = model.maxpool(features)

        features = model.layer1(features)
        features = model.layer2(features)
        features = model.layer3(features)
        features = model.layer4(features)
        features = model.avgpool(features)
        
    return features

# %%
features = []
for training_image in training_images:
    features.append(get_image_feature(DATASET_PATH + training_image))

# %%
print(len(features))
# Out:
# 30000

# %%
torch.cat((description_features[0], features[0].flatten())).shape
concat_features = []
for i in range(len(features)):
    concat_features.append(torch.cat((description_features[i], features[i].flatten())))

# %%
print(len(concat_features))
# Out:
# 30000

# %%
print(concat_features[0].shape)
print(torch.ones((len(concat_features))))
# Out:
# torch.Size([1280])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])

# %%
# Définir une classe Dataset pour vos données d'entraînement
class ImageDescDataset(Dataset):
    def __init__(self, features, similarities):
        self.features = features
        self.similarities = similarities
        
    def __len__(self):
        return len(self.features)
    
    def __getitem__(self, idx):
        feature = self.features[idx]
        similarity = self.similarities[idx]
        return feature, similarity

# Définir votre modèle
class SimilarityModel(nn.Module):
    def __init__(self, input_size):
        super(SimilarityModel, self).__init__()
        hidden_size = input_size // 2
        self.fc1 = nn.Linear(input_size, hidden_size)
        
        input_size = hidden_size
        hidden_size = input_size // 2
        self.fc2 = nn.Linear(input_size, hidden_size)
        
        input_size = hidden_size
        hidden_size = input_size // 2
        self.fc3 = nn.Linear(input_size, hidden_size)
        
        input_size = hidden_size
        self.fc4 = nn.Linear(input_size, 1)
        
    def forward(self, features):
        x = features
        x = self.fc1(x)
        x = torch.relu(x)
        x = self.fc2(x)
        x = torch.relu(x)
        x = self.fc3(x)
        x = torch.relu(x)
        x = self.fc4(x)
        x = torch.sigmoid(x)
        return x

# %%
# Définir votre fonction de perte et l'optimiseur
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

features = concat_features
similarities = torch.ones((len(concat_features))).to(device)
train_dataset = ImageDescDataset(features[:24000], similarities[:24000])
val_dataset = ImageDescDataset(features[24000:27000], similarities[24000:27000])
test_dataset = ImageDescDataset(features[27000:], similarities[27000:])

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

model = SimilarityModel(input_size=1280).to(device)

for epoch in range(EPOCHS):
     # Boucle d'entraînement
    for i, (feature, similarity) in enumerate(train_loader):
        optimizer.zero_grad()
        outputs = model(feature)
        loss = criterion(outputs, similarity)
        loss.backward()
        optimizer.step()
        # Afficher la perte toutes les 50 itérations
        if (i+1) % 50 == 0:
            print(f'Epoch {epoch+1}, iteration {i+1}, loss = {loss.item()}')
    
    # Boucle de validation
    with torch.no_grad():
        total_loss = 0
        for feature, similarity in val_loader:
            outputs = model(feature)
            loss = criterion(outputs, similarity)
            total_loss += loss.item() * image_features.size(0)
        val_loss = total_loss / len(val_dataset)
        print(f'Epoch {epoch+1}, validation loss = {val_loss}')
        
# Tester les performances de votre modèle sur l'ensemble de test
with torch.no_grad():
    total_loss = 0
    for feature, similarity in test_loader:
        outputs = model(feature)
        loss = criterion(outputs, similarity)
# Epoch 2, iteration 1200, loss = 0.24592968821525574
# Epoch 2, iteration 1250, loss = 0.24614298343658447
# Epoch 2, iteration 1300, loss = 0.245889812707901
# Epoch 2, iteration 1350, loss = 0.2452956885099411
# Epoch 2, iteration 1400, loss = 0.24530239403247833
# Epoch 2, iteration 1450, loss = 0.24548274278640747
# Epoch 2, iteration 1500, loss = 0.24555185437202454
# Epoch 2, validation loss = 0.12303574927647909
# Epoch 3, iteration 50, loss = 0.24501144886016846
# Epoch 3, iteration 100, loss = 0.245208740234375
# Epoch 3, iteration 150, loss = 0.24537870287895203
# Epoch 3, iteration 200, loss = 0.24544115364551544
# Epoch 3, iteration 250, loss = 0.2456338107585907
# Epoch 3, iteration 300, loss = 0.24529901146888733
# Epoch 3, iteration 350, loss = 0.24575108289718628
# Epoch 3, iteration 400, loss = 0.2451011836528778
# Epoch 3, iteration 450, loss = 0.24522759020328522
# Epoch 3, iteration 500, loss = 0.24528434872627258
# Epoch 3, iteration 550, loss = 0.24535386264324188
# Epoch 3, iteration 600, loss = 0.24476850032806396
# Epoch 3, iteration 650, loss = 0.24507369101047516
# Epoch 3, iteration 700, loss = 0.24554632604122162
# Epoch 3, iteration 750, loss = 0.24593187868595123
# Epoch 3, iteration 800, loss = 0.24529054760932922
# Epoch 3, iteration 850, loss = 0.24580955505371094
# Epoch 3, iteration 900, loss = 0.2455083280801773
# Epoch 3, iteration 950, loss = 0.24465243518352509
# Epoch 3, iteration 1000, loss = 0.24535594880580902
# Epoch 3, iteration 1050, loss = 0.24520425498485565
# Epoch 3, iteration 1100, loss = 0.245458722114563
# Epoch 3, iteration 1150, loss = 0.24553732573986053
# Epoch 3, iteration 1200, loss = 0.245267853140831
# Epoch 3, iteration 1250, loss = 0.24547897279262543
# Epoch 3, iteration 1300, loss = 0.24546131491661072
# Epoch 3, iteration 1350, loss = 0.24546140432357788
# Epoch 3, iteration 1400, loss = 0.24529805779457092
# Epoch 3, iteration 1450, loss = 0.24530524015426636
# Epoch 3, iteration 1500, loss = 0.24527332186698914
# Epoch 3, validation loss = 0.12303574927647909
# Epoch 4, iteration 50, loss = 0.2454034388065338
# Epoch 4, iteration 100, loss = 0.2454644739627838
# Epoch 4, iteration 150, loss = 0.24489423632621765
# Epoch 4, iteration 200, loss = 0.24609613418579102
# Epoch 4, iteration 250, loss = 0.2458663135766983
# Epoch 4, iteration 300, loss = 0.2452358901500702
# Epoch 4, iteration 350, loss = 0.2453521490097046
# Epoch 4, iteration 400, loss = 0.24530553817749023
# Epoch 4, iteration 450, loss = 0.24548259377479553
# Epoch 4, iteration 500, loss = 0.24488118290901184
# Epoch 4, iteration 550, loss = 0.2447582185268402
# Epoch 4, iteration 600, loss = 0.2452244609594345
# Epoch 4, iteration 650, loss = 0.24475744366645813
# Epoch 4, iteration 700, loss = 0.24551470577716827
# Epoch 4, iteration 750, loss = 0.24565036594867706
# Epoch 4, iteration 800, loss = 0.24581095576286316
# Epoch 4, iteration 850, loss = 0.2453780621290207
# Epoch 4, iteration 900, loss = 0.24507486820220947
# Epoch 4, iteration 950, loss = 0.24489298462867737
# Epoch 4, iteration 1000, loss = 0.24570325016975403
# Epoch 4, iteration 1050, loss = 0.2453431487083435
# Epoch 4, iteration 1100, loss = 0.24565500020980835
# Epoch 4, iteration 1150, loss = 0.24496088922023773
# Epoch 4, iteration 1200, loss = 0.2450600564479828
# Epoch 4, iteration 1250, loss = 0.24482187628746033
# Epoch 4, iteration 1300, loss = 0.2455064058303833
# Epoch 4, iteration 1350, loss = 0.24573154747486115
# Epoch 4, iteration 1400, loss = 0.24552805721759796
# Epoch 4, iteration 1450, loss = 0.24568074941635132
# Epoch 4, iteration 1500, loss = 0.24525924026966095
# Epoch 4, validation loss = 0.12303574927647909
# Epoch 5, iteration 50, loss = 0.24510829150676727
# Epoch 5, iteration 100, loss = 0.2455003410577774
# Epoch 5, iteration 150, loss = 0.24549594521522522
# Epoch 5, iteration 200, loss = 0.24583378434181213
# Epoch 5, iteration 250, loss = 0.2454938143491745
# Epoch 5, iteration 300, loss = 0.24613289535045624
# Epoch 5, iteration 350, loss = 0.24610665440559387
# Epoch 5, iteration 400, loss = 0.24564197659492493
# Epoch 5, iteration 450, loss = 0.24527308344841003
# Epoch 5, iteration 500, loss = 0.24604488909244537
# Epoch 5, iteration 550, loss = 0.2455565184354782
# Epoch 5, iteration 600, loss = 0.2458333969116211
# Epoch 5, iteration 650, loss = 0.245238795876503
# Epoch 5, iteration 700, loss = 0.2454034835100174
# Epoch 5, iteration 750, loss = 0.24523219466209412
# Epoch 5, iteration 800, loss = 0.24470454454421997
# Epoch 5, iteration 850, loss = 0.24513079226016998
# Epoch 5, iteration 900, loss = 0.2452719658613205
# Epoch 5, iteration 950, loss = 0.24563616514205933
# Epoch 5, iteration 1000, loss = 0.24523721635341644
# Epoch 5, iteration 1050, loss = 0.24476104974746704
# Epoch 5, iteration 1100, loss = 0.24519044160842896
# Epoch 5, iteration 1150, loss = 0.2456175535917282
# Epoch 5, iteration 1200, loss = 0.24536092579364777
# Epoch 5, iteration 1250, loss = 0.24572207033634186
# Epoch 5, iteration 1300, loss = 0.24569690227508545
# Epoch 5, iteration 1350, loss = 0.2453092634677887
# Epoch 5, iteration 1400, loss = 0.24545162916183472
# Epoch 5, iteration 1450, loss = 0.24501347541809082
# Epoch 5, iteration 1500, loss = 0.24512919783592224
# Epoch 5, validation loss = 0.12303574927647909
# Epoch 6, iteration 50, loss = 0.24585849046707153
# Epoch 6, iteration 100, loss = 0.2449691742658615
# Epoch 6, iteration 150, loss = 0.24534504115581512
# Epoch 6, iteration 200, loss = 0.24530169367790222
# Epoch 6, iteration 250, loss = 0.24530979990959167
# Epoch 6, iteration 300, loss = 0.2453813999891281
# Epoch 6, iteration 350, loss = 0.24495647847652435
# Epoch 6, iteration 400, loss = 0.24546384811401367
# Epoch 6, iteration 450, loss = 0.24575087428092957
# Epoch 6, iteration 500, loss = 0.24524980783462524
# Epoch 6, iteration 550, loss = 0.24578335881233215
# Epoch 6, iteration 600, loss = 0.24601368606090546
# Epoch 6, iteration 650, loss = 0.2453911155462265
# Epoch 6, iteration 700, loss = 0.2452819049358368
# Epoch 6, iteration 750, loss = 0.2455797642469406
# Epoch 6, iteration 800, loss = 0.24531464278697968
# Epoch 6, iteration 850, loss = 0.24590924382209778
# Epoch 6, iteration 900, loss = 0.24604281783103943
# Epoch 6, iteration 950, loss = 0.24571385979652405
# Epoch 6, iteration 1000, loss = 0.2453070431947708
# Epoch 6, iteration 1050, loss = 0.24562469124794006
# Epoch 6, iteration 1100, loss = 0.24568216502666473
# Epoch 6, iteration 1150, loss = 0.2448091208934784
# Epoch 6, iteration 1200, loss = 0.24536064267158508
# Epoch 6, iteration 1250, loss = 0.24481819570064545
# Epoch 6, iteration 1300, loss = 0.24600903689861298
# Epoch 6, iteration 1350, loss = 0.2454943209886551
# Epoch 6, iteration 1400, loss = 0.245467409491539
# Epoch 6, iteration 1450, loss = 0.24566060304641724
# Epoch 6, iteration 1500, loss = 0.24580726027488708
# Epoch 6, validation loss = 0.12303574927647909
# Epoch 7, iteration 50, loss = 0.2457132488489151
# Epoch 7, iteration 100, loss = 0.24496416747570038
# Epoch 7, iteration 150, loss = 0.24559186398983002
# Epoch 7, iteration 200, loss = 0.24546220898628235
# Epoch 7, iteration 250, loss = 0.2450598180294037
# Epoch 7, iteration 300, loss = 0.24501515924930573
# Epoch 7, iteration 350, loss = 0.24539783596992493
# Epoch 7, iteration 400, loss = 0.2451029270887375
# Epoch 7, iteration 450, loss = 0.24557067453861237
# Epoch 7, iteration 500, loss = 0.24445165693759918
# Epoch 7, iteration 550, loss = 0.24512627720832825
# Epoch 7, iteration 600, loss = 0.24539095163345337
# Epoch 7, iteration 650, loss = 0.24582983553409576
# Epoch 7, iteration 700, loss = 0.24534980952739716
# Epoch 7, iteration 750, loss = 0.245520681142807
# Epoch 7, iteration 800, loss = 0.24533337354660034
# Epoch 7, iteration 850, loss = 0.2460423707962036
# Epoch 7, iteration 900, loss = 0.24527579545974731
# Epoch 7, iteration 950, loss = 0.24553847312927246
# Epoch 7, iteration 1000, loss = 0.244867742061615
# Epoch 7, iteration 1050, loss = 0.24478819966316223
# Epoch 7, iteration 1100, loss = 0.24513950943946838
# Epoch 7, iteration 1150, loss = 0.2452603578567505
# Epoch 7, iteration 1200, loss = 0.2451767921447754
# Epoch 7, iteration 1250, loss = 0.24553930759429932
# Epoch 7, iteration 1300, loss = 0.2453053891658783
# Epoch 7, iteration 1350, loss = 0.24554935097694397
# Epoch 7, iteration 1400, loss = 0.24534834921360016
# Epoch 7, iteration 1450, loss = 0.2459450364112854
# Epoch 7, iteration 1500, loss = 0.24504470825195312
# Epoch 7, validation loss = 0.12303574927647909
# Epoch 8, iteration 50, loss = 0.24546512961387634
# Epoch 8, iteration 100, loss = 0.24566510319709778
# Epoch 8, iteration 150, loss = 0.24516355991363525
# Epoch 8, iteration 200, loss = 0.24544104933738708
# Epoch 8, iteration 250, loss = 0.24526852369308472
# Epoch 8, iteration 300, loss = 0.24577447772026062
# Epoch 8, iteration 350, loss = 0.24486295878887177
# Epoch 11, iteration 1400, loss = 0.24538008868694305
# Epoch 11, iteration 1450, loss = 0.24541515111923218
# Epoch 11, iteration 1500, loss = 0.24562735855579376
# Epoch 11, validation loss = 0.12303574927647909
# Epoch 12, iteration 50, loss = 0.24533769488334656
# Epoch 12, iteration 100, loss = 0.24576550722122192
# Epoch 12, iteration 150, loss = 0.24602997303009033
# Epoch 12, iteration 200, loss = 0.2450554370880127
# Epoch 12, iteration 250, loss = 0.2458200752735138
# Epoch 12, iteration 300, loss = 0.24538956582546234
# Epoch 12, iteration 350, loss = 0.2460203766822815
# Epoch 12, iteration 400, loss = 0.24557766318321228
# Epoch 12, iteration 450, loss = 0.24563176929950714
# Epoch 12, iteration 500, loss = 0.24557998776435852
# Epoch 12, iteration 550, loss = 0.24492034316062927
# Epoch 12, iteration 600, loss = 0.24531711637973785
# Epoch 12, iteration 650, loss = 0.24547725915908813
# Epoch 12, iteration 700, loss = 0.24551665782928467
# Epoch 12, iteration 750, loss = 0.24531827867031097
# Epoch 12, iteration 800, loss = 0.24554488062858582
# Epoch 12, iteration 850, loss = 0.2451317012310028
# Epoch 12, iteration 900, loss = 0.24537596106529236
# Epoch 12, iteration 950, loss = 0.24527955055236816
# Epoch 12, iteration 1000, loss = 0.24576854705810547
# Epoch 12, iteration 1050, loss = 0.2452659159898758
# Epoch 12, iteration 1100, loss = 0.24583765864372253
# Epoch 12, iteration 1150, loss = 0.24594388902187347
# Epoch 12, iteration 1200, loss = 0.24528446793556213
# Epoch 12, iteration 1250, loss = 0.24534374475479126
# Epoch 12, iteration 1300, loss = 0.24601691961288452
# Epoch 12, iteration 1350, loss = 0.24512849748134613
# Epoch 12, iteration 1400, loss = 0.24546031653881073
# Epoch 12, iteration 1450, loss = 0.24589377641677856
# Epoch 12, iteration 1500, loss = 0.2453288435935974
# Epoch 12, validation loss = 0.12303574927647909
# Epoch 13, iteration 50, loss = 0.24589817225933075
# Epoch 13, iteration 100, loss = 0.24522075057029724
# Epoch 13, iteration 150, loss = 0.24534596502780914
# Epoch 13, iteration 200, loss = 0.24549701809883118
# Epoch 13, iteration 250, loss = 0.24522778391838074
# Epoch 13, iteration 300, loss = 0.24453669786453247
# Epoch 13, iteration 350, loss = 0.24590562283992767
# Epoch 13, iteration 400, loss = 0.24507740139961243
# Epoch 13, iteration 450, loss = 0.24581526219844818
# Epoch 13, iteration 500, loss = 0.24493467807769775
# Epoch 13, iteration 550, loss = 0.246292382478714
# Epoch 13, iteration 600, loss = 0.24541336297988892
# Epoch 13, iteration 650, loss = 0.24505913257598877
# Epoch 13, iteration 700, loss = 0.24541348218917847
# Epoch 13, iteration 750, loss = 0.24531827867031097
# Epoch 13, iteration 800, loss = 0.24509522318840027
# Epoch 13, iteration 850, loss = 0.24466738104820251
# Epoch 13, iteration 900, loss = 0.24575521051883698
# Epoch 13, iteration 950, loss = 0.24601365625858307
# Epoch 13, iteration 1000, loss = 0.24476397037506104
# Epoch 13, iteration 1050, loss = 0.2454695701599121
# Epoch 13, iteration 1100, loss = 0.24558421969413757
# Epoch 13, iteration 1150, loss = 0.2449275404214859
# Epoch 13, iteration 1200, loss = 0.2455751895904541
# Epoch 13, iteration 1250, loss = 0.2456565499305725
# Epoch 13, iteration 1300, loss = 0.24514631927013397
# Epoch 13, iteration 1350, loss = 0.24516718089580536
# Epoch 13, iteration 1400, loss = 0.24537572264671326
# Epoch 13, iteration 1450, loss = 0.24500595033168793
# Epoch 13, iteration 1500, loss = 0.24553611874580383
# Epoch 13, validation loss = 0.12303574927647909
# Epoch 14, iteration 50, loss = 0.24567624926567078
# Epoch 14, iteration 100, loss = 0.2457042932510376
# Epoch 14, iteration 150, loss = 0.24579370021820068
# Epoch 14, iteration 200, loss = 0.2450685203075409
# Epoch 14, iteration 250, loss = 0.24534787237644196
# Epoch 14, iteration 300, loss = 0.24503076076507568
# Epoch 14, iteration 350, loss = 0.24481266736984253
# Epoch 14, iteration 400, loss = 0.2458382099866867
# Epoch 14, iteration 450, loss = 0.2451155036687851
# Epoch 14, iteration 500, loss = 0.2452632486820221
# Epoch 14, iteration 550, loss = 0.24518686532974243
# Epoch 14, iteration 600, loss = 0.24535652995109558
# Epoch 14, iteration 650, loss = 0.24567753076553345
# Epoch 14, iteration 700, loss = 0.24550899863243103
# Epoch 14, iteration 750, loss = 0.24579204618930817
# Epoch 14, iteration 800, loss = 0.24504193663597107
# Epoch 14, iteration 850, loss = 0.24597617983818054
# Epoch 14, iteration 900, loss = 0.2452622652053833
# Epoch 14, iteration 950, loss = 0.24543356895446777
# Epoch 14, iteration 1000, loss = 0.24496665596961975
# Epoch 14, iteration 1050, loss = 0.24498192965984344
# Epoch 14, iteration 1100, loss = 0.2457447052001953
# Epoch 14, iteration 1150, loss = 0.24497468769550323
# Epoch 14, iteration 1200, loss = 0.24540844559669495
# Epoch 14, iteration 1250, loss = 0.24586129188537598
# Epoch 14, iteration 1300, loss = 0.24454063177108765
# Epoch 14, iteration 1350, loss = 0.2453271746635437
# Epoch 14, iteration 1400, loss = 0.2449999451637268
# Epoch 14, iteration 1450, loss = 0.24547025561332703
# Epoch 14, iteration 1500, loss = 0.24519789218902588
# Epoch 14, validation loss = 0.12303574927647909
# Epoch 15, iteration 50, loss = 0.2450772225856781
# Epoch 15, iteration 100, loss = 0.24550026655197144
# Epoch 15, iteration 150, loss = 0.2451707124710083
# Epoch 15, iteration 200, loss = 0.24573224782943726
# Epoch 15, iteration 250, loss = 0.2454666644334793
# Epoch 15, iteration 300, loss = 0.24552106857299805
# Epoch 15, iteration 350, loss = 0.24513891339302063
# Epoch 15, iteration 400, loss = 0.24587363004684448
# Epoch 15, iteration 450, loss = 0.24534070491790771
# Epoch 15, iteration 500, loss = 0.24561476707458496
# Epoch 15, iteration 550, loss = 0.24510890245437622
# Epoch 15, iteration 600, loss = 0.24571456015110016
# Epoch 15, iteration 650, loss = 0.24600253999233246
# Epoch 15, iteration 700, loss = 0.24512329697608948
# Epoch 15, iteration 750, loss = 0.2449580729007721
# Epoch 15, iteration 800, loss = 0.24579721689224243
# Epoch 15, iteration 850, loss = 0.24545234441757202
# Epoch 19, iteration 350, loss = 0.24487647414207458
# Epoch 19, iteration 400, loss = 0.2462817132472992
# Epoch 19, iteration 450, loss = 0.24562355875968933
# Epoch 19, iteration 500, loss = 0.2448914498090744
# Epoch 19, iteration 550, loss = 0.2456790655851364
# Epoch 19, iteration 600, loss = 0.2449766844511032
# Epoch 19, iteration 650, loss = 0.24524691700935364
# Epoch 19, iteration 700, loss = 0.2457461655139923
# Epoch 19, iteration 750, loss = 0.24513565003871918
# Epoch 19, iteration 800, loss = 0.24548450112342834
# Epoch 19, iteration 850, loss = 0.24585214257240295
# Epoch 19, iteration 900, loss = 0.24571195244789124
# Epoch 19, iteration 950, loss = 0.24504253268241882
# Epoch 19, iteration 1000, loss = 0.24542135000228882
# Epoch 19, iteration 1050, loss = 0.24504593014717102
# Epoch 19, iteration 1100, loss = 0.24542540311813354
# Epoch 19, iteration 1150, loss = 0.2454715520143509
# Epoch 19, iteration 1200, loss = 0.24604767560958862
# Epoch 19, iteration 1250, loss = 0.24508631229400635
# Epoch 19, iteration 1300, loss = 0.24526116251945496
# Epoch 19, iteration 1350, loss = 0.24597692489624023
# Epoch 19, iteration 1400, loss = 0.24512696266174316
# Epoch 19, iteration 1450, loss = 0.2459031492471695
# Epoch 19, iteration 1500, loss = 0.24507664144039154
# Epoch 19, validation loss = 0.12303574927647909
# Epoch 20, iteration 50, loss = 0.24549971520900726
# Epoch 20, iteration 100, loss = 0.2449047714471817
# Epoch 20, iteration 150, loss = 0.24538269639015198
# Epoch 20, iteration 200, loss = 0.24574798345565796
# Epoch 20, iteration 250, loss = 0.24520911276340485
# Epoch 20, iteration 300, loss = 0.24497424066066742
# Epoch 20, iteration 350, loss = 0.24530592560768127
# Epoch 20, iteration 400, loss = 0.24608394503593445
# Epoch 20, iteration 450, loss = 0.24544042348861694
# Epoch 20, iteration 500, loss = 0.24573218822479248
# Epoch 20, iteration 550, loss = 0.2452593743801117
# Epoch 20, iteration 600, loss = 0.2451600432395935
# Epoch 20, iteration 650, loss = 0.2451097071170807
# Epoch 20, iteration 700, loss = 0.2454598844051361
# Epoch 20, iteration 750, loss = 0.2457164227962494
# Epoch 20, iteration 800, loss = 0.24537420272827148
# Epoch 20, iteration 850, loss = 0.2454407811164856
# Epoch 20, iteration 900, loss = 0.24558471143245697
# Epoch 20, iteration 950, loss = 0.24522483348846436
# Epoch 20, iteration 1000, loss = 0.2453301101922989
# Epoch 20, iteration 1050, loss = 0.2452140897512436
# Epoch 20, iteration 1100, loss = 0.2450777292251587
# Epoch 20, iteration 1150, loss = 0.24578386545181274
# Epoch 20, iteration 1200, loss = 0.24539104104042053
# Epoch 20, iteration 1250, loss = 0.24519029259681702
# Epoch 20, iteration 1300, loss = 0.24554815888404846
# Epoch 20, iteration 1350, loss = 0.24589695036411285
# Epoch 20, iteration 1400, loss = 0.24496081471443176
# Epoch 20, iteration 1450, loss = 0.24489280581474304
# Epoch 20, iteration 1500, loss = 0.24522356688976288
# Epoch 20, validation loss = 0.12303574927647909
# Test loss = 0.12303370769818624
